# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn import tree

# %%
data = pd.read_csv('/Users/ibrahimasad/Desktop/untitled folder/BC.csv') #Imported Data from Desktop

# %%
#X = data[['radius_mean', 'texture_mean','perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean' ]]
y = data['diagnosis']

X = data.drop('diagnosis', axis=1)
#y = data.diagnosis.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
#Classification Decison Tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
plt.figure(figsize=(12,12))  # set plot size (denoted in inches)
tree.plot_tree(clf, fontsize=10)
plt.show()

# %%
r2 = clf.score(X_test, y_test)
print(r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w3/zgcq_06x1k3_6m0lgff0tp9r0000gn/T/ipykernel_726/2344046217.py in <module>
# ----> 1 r2 = clf.score(X_test, y_test)
#       2 print(r2)
#
# NameError: name 'clf' is not defined

# %%
#Nearest Neighbour

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier

# %%
dat = pd.read_csv('/Users/ibrahimasad/Desktop/untitled folder/BC.csv') #Imported Data from Desktop

# %%
y1 = dat['diagnosis']

X1 = dat.drop('diagnosis', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_trai, X_tes, y_trai, y_tes = train_test_split(X1, y1, test_size=0.20)

# %%
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
r3 = clf.score(X_tes, y_tes)
print(r3)
# Out:
# 0.9824561403508771

# %%
#Linear Discriminate Analysis

# %%
import numpy as np
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn import tree
from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
da = pd.read_csv('/Users/ibrahimasad/Desktop/untitled folder/BC.csv') #Imported Data from Desktop

# %%
y2 = da['diagnosis']

X2 = da.drop('diagnosis', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_tra, X_te, y_tra, y_te = train_test_split(X2, y2, test_size=0.20)

# %%
cl = RidgeClassifier().fit(X_tra, y_tra)
r4 = cl.score(X_te, y_te)
print(r4)
